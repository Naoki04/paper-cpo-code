# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
wandb.ai/naoki-shitanda/sapg_shadow_hand
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: could not convert string to float: '"589824"'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 # cvs読み込み
#       2 csv_path = "/home/mil/shitanda/CPO_NeurIPS2025/data/0_performance/1_ShadowHand/1_SAPG_s0-4.csv"
# ----> 3 data = np.loadtxt(csv_path, delimiter=",", skiprows=1)
#       5 data.shape
#
# File ~/.pyenv/versions/anaconda3-2023.03/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# ...
