# %%
csv_path = "/home/mil/shitanda/cpo-add/train_dir/allegro_kuka_reorientation/0725-1-0.001-1-0.1-0-0-5class_24576envs_mixed_expl_learn_param_lf_1p_26_07_02h48m36s_seed4/runs/importance_ratios.csv"
